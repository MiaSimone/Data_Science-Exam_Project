# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Because we have a car dataset, the visualisation could be a very large parkinglot in which you stand and the cars would be parked in rows as if the graph of the data was laying on the ground. Every car would have a color and if you park a car in another row it would change color because the car make then would have changed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The above drawing indicates a 1 dimensional idea of what we imagine. The cars each has it's color and looks like the graph above. If this should be a VR concept this would of couse be 3 dimensional so you could stand amoung the cars and drive them to another parking spot by selecting them.
# <br><br>
# The benefit of this solution makes the data seem more clear to the user in a fun way.
