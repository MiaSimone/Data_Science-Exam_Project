# %%
#Imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Carlist

# %%
df_carList = pd.read_csv("datasets/Car_listings.csv", delimiter=",")

# %%
df_carList.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
df_carList.shape
# Out:
# (852122, 8)

# %%
df_carList.dtypes
# Out:
# Price       int64
# Year        int64
# Mileage     int64
# City       object
# State      object
# Vin        object
# Make       object
# Model      object
# dtype: object

# %%
df_carList.describe()
# Out:
#                Price           Year       Mileage
# count  852122.000000  852122.000000  8.521220e+05
# mean    21464.100210    2013.289145  5.250779e+04
# std     13596.202241       3.414987  4.198896e+04
# min      1500.000000    1997.000000  5.000000e+00
# 25%     13000.000000    2012.000000  2.383600e+04
# 50%     18500.000000    2014.000000  4.025600e+04
# 75%     26995.000000    2016.000000  7.218600e+04
# max    499500.000000    2018.000000  2.856196e+06

# %%
# Vin is removed because it has no relevance for polution and the fuel consumption
# further the Fuel consumption tables are general for the car models
df_carList = df_carList.drop(['Vin'], axis = 1)

# %%
#checking if there are any naN values
df_carList.isnull().values.any()
# Out:
# False

# %%
#checking if there are any missing values
df_carList.isnull().sum()
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Make       0
# Model      0
# dtype: int64

# %%
# Uppercase to match fuel consumption later on
df_carList['Make'] = df_carList['Make'].str.upper()
df_carList['Model'] = df_carList['Model'].str.upper()
df_carList['State'] = df_carList['State'].str.upper()
df_carList['City'] = df_carList['City'].str.upper()

# %%
df_carList.head()
# Out:
#    Price  Year  Mileage              City State   Make         Model
# 0   8995  2014    35725           EL PASO    TX  ACURA    ILX6-SPEED
# 1  10888  2013    19606  LONG ISLAND CITY    NY  ACURA    ILX5-SPEED
# 2   8995  2013    48851           EL PASO    TX  ACURA    ILX6-SPEED
# 3  10999  2014    39922           WINDSOR    CO  ACURA    ILX5-SPEED
# 4  14799  2016    22142            LINDON    UT  ACURA  ILXAUTOMATIC

# %% [markdown]
# ### Is there a connection between the car model and it’s price? NOT DONE

# %%
df_groupList = df_carList.groupby(['Make', 'Model']).mean()
df_groupList
# Out:
#                            Price         Year        Mileage
# Make  Model
# ACURA CLAUTOMATIC    4492.666667  1998.833333  138889.500000
#       CLMANUAL       4493.000000  1999.000000  175414.500000
#       CLTYPE-S       5207.736842  2001.894737  145691.421053
#       ILX4DR        15490.000000  2015.000000   40131.000000
#       ILX5-SPEED    17214.413636  2014.460606   36734.303030
# ...                          ...          ...            ...
# VOLVO XC90PREMIER   26982.000000  2013.000000   56487.000000
#       XC90R-DESIGN  18498.000000  2013.000000   92732.000000
#       XC90T5        48085.615385  2017.153846    7999.461538
#       XC90T6        52773.702381  2016.845238   12794.785714
#       XC90T8        68836.777778  2017.000000    6438.000000
#
# [2718 rows x 3 columns]

# %%
df_Acura = df_carList.loc[df_carList['Make'] == 'ACURA']
df_Acura = df_Acura.groupby(['Model', 'Year']).mean()
df_Acura
# Out:
#                          Price        Mileage
# Model       Year
# CLAUTOMATIC 1997   4492.500000  143537.500000
#             1998   4495.000000   93969.000000
#             1999   2981.000000  224765.000000
#             2001   5247.500000  113764.000000
# CLMANUAL    1999   4493.000000  175414.500000
# ...                        ...            ...
# TSXV6       2012  14492.500000  102260.500000
# ZDXAWD      2010  19679.400000   77497.150000
#             2011  22639.714286   64160.428571
#             2012  18889.333333   84390.666667
# ZDXBASE     2013  25895.000000   52205.000000
#
# [185 rows x 2 columns]

# %%
df_Acura['Price'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Model,Year'>

# %% [markdown]
# # Fuel Consumption

# %%
df_2022Fuel = pd.read_csv("datasets/2022_Fuel_Consumption_Ratings.csv", delimiter=";")

# %%
df_2022Fuel.head()
# Out:
#    YEAR   MAKE              MODEL VEHICLE CLASS  ENGINE SIZE(L)  CYLINDERS  \
# 0  2022  Acura                ILX       Compact             2.4          4
# 1  2022  Acura         MDX SH-AWD    SUV: Small             3.5          6
# 2  2022  Acura         RDX SH-AWD    SUV: Small             2.0          4
# 3  2022  Acura  RDX SH-AWD A-SPEC    SUV: Small             2.0          4
# 4  2022  Acura         TLX SH-AWD       Compact             2.0          4
#
#   TRANSMISSION FUELTYPE  CITY (L/100 km)  HWY (L/100 km)  COMB (L/100 km)  \
# 0          AM8        Z              9.9             7.0              8.6
# 1         AS10        Z             12.6             9.4             11.2
# 2         AS10        Z             11.0             8.6              9.9
# 3         AS10        Z             11.3             9.1             10.3
# 4         AS10        Z             11.2             8.0              9.8
#
#    COMB (mpg)  CO2 EMISSIONS  CO2 RATING  SMOG RATING
# 0          33            200           6            3
# 1          25            263           4            5
# 2          29            232           5            6
# 3          27            242           5            6
# 4          29            230           5            7

# %%
df_1990Fuel = pd.read_csv("datasets/1995-1999_Fuel_Consumption_Ratings.csv", delimiter=";")

# %% [markdown]
# CITY HWY COMB = fuel Consumption

# %%
df_1990Fuel.head()
# Out:
#    YEAR   MAKE         MODEL VEHICLE CLASS  ENGINE SIZE(L)  CYLINDERS  \
# 0  1995  ACURA       INTEGRA    SUBCOMPACT             1.8          4
# 1  1995  ACURA       INTEGRA    SUBCOMPACT             1.8          4
# 2  1995  ACURA  INTEGRA GS-R    SUBCOMPACT             1.8          4
# 3  1995  ACURA        LEGEND       COMPACT             3.2          6
# 4  1995  ACURA  LEGEND COUPE       COMPACT             3.2          6
#
#   TRANSMISSION FUELTYPE  CITY (L/100 km)  HWY (L/100 km)  COMB (L/100 km)  \
# 0           A4        X             11.6             8.3             10.1
# 1           M5        X             11.0             8.3              9.8
# 2           M5        Z             10.8             8.3              9.7
# 3           A4        Z             14.2            10.5             12.5
# 4           A4        Z             14.6            11.0             13.0
#
#    COMB (mpg)  CO2 EMISSIONS
# 0          28            232
# 1          29            225
# 2          29            223
# 3          23            288
# 4          22            299

# %% [markdown]
# ## Merched

# %%
#merching fuel dataframes to a combined new one
merge = [df_1990Fuel, df_2022Fuel]
df_fuel = pd.concat(merge, axis=0)
df_fuel
# Out:
#      YEAR   MAKE         MODEL  VEHICLE CLASS  ENGINE SIZE(L)  CYLINDERS  \
# 0    1995  ACURA       INTEGRA     SUBCOMPACT             1.8          4
# 1    1995  ACURA       INTEGRA     SUBCOMPACT             1.8          4
# 2    1995  ACURA  INTEGRA GS-R     SUBCOMPACT             1.8          4
# 3    1995  ACURA        LEGEND        COMPACT             3.2          6
# 4    1995  ACURA  LEGEND COUPE        COMPACT             3.2          6
# ..    ...    ...           ...            ...             ...        ...
# 941  2022  Volvo   XC40 T5 AWD     SUV: Small             2.0          4
# 942  2022  Volvo   XC60 B5 AWD     SUV: Small             2.0          4
# 943  2022  Volvo   XC60 B6 AWD     SUV: Small             2.0          4
# 944  2022  Volvo   XC90 T5 AWD  SUV: Standard             2.0          4
# 945  2022  Volvo   XC90 T6 AWD  SUV: Standard             2.0          4
#
#     TRANSMISSION FUELTYPE  CITY (L/100 km)  HWY (L/100 km)  COMB (L/100 km)  \
# 0             A4        X             11.6             8.3             10.1
# 1             M5        X             11.0             8.3              9.8
# 2             M5        Z             10.8             8.3              9.7
# 3             A4        Z             14.2            10.5             12.5
# 4             A4        Z             14.6            11.0             13.0
# ..           ...      ...              ...             ...              ...
# 941          AS8        Z             10.7             7.7              9.4
# 942          AS8        Z             10.5             8.1              9.4
# 943          AS8        Z             11.0             8.7              9.9
# 944          AS8        Z             11.5             8.4             10.1
# 945          AS8        Z             12.4             8.9             10.8
#
#      COMB (mpg)  CO2 EMISSIONS  CO2 RATING  SMOG RATING
# 0            28            232         NaN          NaN
# 1            29            225         NaN          NaN
# 2            29            223         NaN          NaN
# 3            23            288         NaN          NaN
# 4            22            299         NaN          NaN
# ..          ...            ...         ...          ...
# 941          30            219         5.0          5.0
# 942          30            219         5.0          5.0
# 943          29            232         5.0          7.0
# 944          28            236         5.0          5.0
# 945          26            252         5.0          7.0
#
# [4465 rows x 15 columns]

# %%
df_fuel.describe()
# Out:
#               YEAR  ENGINE SIZE(L)    CYLINDERS  CITY (L/100 km)  \
# count  4465.000000     4465.000000  4465.000000      4465.000000
# mean   2002.213886        3.316193     5.756999        14.301926
# std      10.340515        1.383030     1.707913         3.564890
# min    1995.000000        1.000000     2.000000         4.000000
# 25%    1996.000000        2.200000     4.000000        11.900000
# 50%    1998.000000        3.000000     6.000000        13.900000
# 75%    1999.000000        4.300000     6.000000        16.300000
# max    2022.000000        8.000000    16.000000        30.300000
#
#        HWY (L/100 km)  COMB (L/100 km)   COMB (mpg)  CO2 EMISSIONS  \
# count     4465.000000      4465.000000  4465.000000    4465.000000
# mean        10.437380        12.563427    23.900784     290.602016
# std          2.577376         3.078139     6.271719      70.259267
# min          3.900000         4.000000    11.000000      94.000000
# 25%          8.700000        10.500000    19.000000     242.000000
# 50%          9.900000        12.200000    23.000000     281.000000
# 75%         12.200000        14.500000    27.000000     334.000000
# max         20.900000        26.100000    71.000000     608.000000
#
#        CO2 RATING  SMOG RATING
# count  946.000000   946.000000
# mean     4.539112     4.950317
# std      1.471799     1.679842
# min      1.000000     1.000000
# 25%      3.000000     3.000000
# 50%      5.000000     5.000000
# 75%      5.000000     6.000000
# max     10.000000     7.000000

# %%
df_fuel.shape
# Out:
# (4465, 15)

# %%
df_fuel.dtypes
# Out:
# YEAR                 int64
# MAKE                object
# MODEL               object
# VEHICLE CLASS       object
# ENGINE SIZE(L)     float64
# CYLINDERS            int64
# TRANSMISSION        object
# FUELTYPE            object
# CITY (L/100 km)    float64
# HWY (L/100 km)     float64
# COMB (L/100 km)    float64
# COMB (mpg)           int64
# CO2 EMISSIONS        int64
# CO2 RATING         float64
# SMOG RATING        float64
# dtype: object

# %%
# CO2 and SMOG RATING are removed because it is only the 2022 models that have the ratings 
# and the dataset is considerably smaller then the 1990 tabel
# we had considered to instert the mean value in the missing rows but it will give a wrong inpression of the 1990 models 
df_fuel = df_fuel.drop(['CO2 RATING', 'SMOG RATING'], axis = 1)

# %%
# the values in this row are identical with COMB (L/100 km) and therefore is not needed, because we don't need the same
# value twice 
df_fuel = df_fuel.drop(['COMB (mpg)'], axis = 1)

# %%
#checking if there are any naN values
df_fuel.isnull().values.any()
# Out:
# False

# %%
#checking if there are any missing values
df_fuel.isnull().sum()
# Out:
# YEAR               0
# MAKE               0
# MODEL              0
# VEHICLE CLASS      0
# ENGINE SIZE(L)     0
# CYLINDERS          0
# TRANSMISSION       0
# FUELTYPE           0
# CITY (L/100 km)    0
# HWY (L/100 km)     0
# COMB (L/100 km)    0
# CO2 EMISSIONS      0
# dtype: int64

# %%
# Uppercase entire dataframe  to  match  CarList 
df_fuel['MAKE'] = df_fuel['MAKE'].str.upper()
df_fuel['MODEL'] = df_fuel['MODEL'].str.upper()
df_fuel['VEHICLE CLASS'] = df_fuel['VEHICLE CLASS'].str.upper()

# %%
df_fuel
# Out:
#      YEAR   MAKE         MODEL  VEHICLE CLASS  ENGINE SIZE(L)  CYLINDERS  \
# 0    1995  ACURA       INTEGRA     SUBCOMPACT             1.8          4
# 1    1995  ACURA       INTEGRA     SUBCOMPACT             1.8          4
# 2    1995  ACURA  INTEGRA GS-R     SUBCOMPACT             1.8          4
# 3    1995  ACURA        LEGEND        COMPACT             3.2          6
# 4    1995  ACURA  LEGEND COUPE        COMPACT             3.2          6
# ..    ...    ...           ...            ...             ...        ...
# 941  2022  VOLVO   XC40 T5 AWD     SUV: SMALL             2.0          4
# 942  2022  VOLVO   XC60 B5 AWD     SUV: SMALL             2.0          4
# 943  2022  VOLVO   XC60 B6 AWD     SUV: SMALL             2.0          4
# 944  2022  VOLVO   XC90 T5 AWD  SUV: STANDARD             2.0          4
# 945  2022  VOLVO   XC90 T6 AWD  SUV: STANDARD             2.0          4
#
#     TRANSMISSION FUELTYPE  CITY (L/100 km)  HWY (L/100 km)  COMB (L/100 km)  \
# 0             A4        X             11.6             8.3             10.1
# 1             M5        X             11.0             8.3              9.8
# 2             M5        Z             10.8             8.3              9.7
# 3             A4        Z             14.2            10.5             12.5
# 4             A4        Z             14.6            11.0             13.0
# ..           ...      ...              ...             ...              ...
# 941          AS8        Z             10.7             7.7              9.4
# 942          AS8        Z             10.5             8.1              9.4
# 943          AS8        Z             11.0             8.7              9.9
# 944          AS8        Z             11.5             8.4             10.1
# 945          AS8        Z             12.4             8.9             10.8
#
#      CO2 EMISSIONS
# 0              232
# 1              225
# 2              223
# 3              288
# 4              299
# ..             ...
# 941            219
# 942            219
# 943            232
# 944            236
# 945            252
#
# [4465 rows x 12 columns]

# %% [markdown]
# ### What models pollute the most?

# %%
df_fuel.sort_values('CO2 EMISSIONS', ascending = False)
# Out:
#       YEAR     MAKE                MODEL VEHICLE CLASS  ENGINE SIZE(L)  \
# 134   2022  BUGATTI   CHIRON SUPER SPORT    TWO-SEATER             8.0
# 133   2022  BUGATTI     CHIRON PUR SPORT    TWO-SEATER             8.0
# 3054  1999  FERRARI        550 MARANELLO    TWO-SEATER             5.5
# 1748  1997  FERRARI                  456    SUBCOMPACT             5.5
# 2406  1998  FERRARI        550 MARANELLO    TWO-SEATER             5.5
# ...    ...      ...                  ...           ...             ...
# 885   2022   TOYOTA       COROLLA HYBRID       COMPACT             1.8
# 895   2022   TOYOTA                PRIUS      MID-SIZE             1.8
# 458   2022  HYUNDAI  ELANTRA HYBRID BLUE      MID-SIZE             1.6
# 459   2022  HYUNDAI                IONIQ     FULL-SIZE             1.6
# 460   2022  HYUNDAI           IONIQ BLUE     FULL-SIZE             1.6
#
#       CYLINDERS TRANSMISSION FUELTYPE  CITY (L/100 km)  HWY (L/100 km)  \
# 134          16          AM7        Z             30.3            20.9
# 133          16          AM7        Z             30.3            20.9
# 3054         12           M6        Z             28.5            18.0
# 1748         12           A4        Z             28.3            17.1
# 2406         12           M6        Z             28.3            17.0
# ...         ...          ...      ...              ...             ...
# 885           4           AV        X              4.4             4.5
# 895           4           AV        X              4.4             4.7
# 458           4          AM6        X              4.5             4.2
# 459           4          AM6        X              4.3             4.1
# 460           4          AM6        X              4.0             3.9
#
#       COMB (L/100 km)  CO2 EMISSIONS
# 134              26.1            608
# 133              26.1            608
# 3054             23.8            547
# 1748             23.3            536
# 2406             23.2            534
# ...               ...            ...
# 885               4.5            106
# 895               4.5            106
# 458               4.4            103
# 459               4.2             99
# 460               4.0             94
#
# [4465 rows x 12 columns]

# %% [markdown]
# the car that pollutes the most is a Bugatti Chiron Super Sport

# %% [markdown]
# ### What models have improved in preventing pollution? NOT DONE

# %%
df_preventPollution = df_fuel.groupby(['MAKE','YEAR']).mean()
d = df_preventPollution['CO2 EMISSIONS']
d.diff().sort_values()
# Out:
# MAKE         YEAR
# BUICK        1995   -299.690476
# FIAT         2022   -292.400000
# LINCOLN      2022   -111.928571
# LAND ROVER   2022   -110.000000
# BENTLEY      2022   -109.525000
#                         ...
# FERRARI      1995    210.916667
# LAMBORGHINI  2022    224.675000
# BENTLEY      1995    237.713889
# BUGATTI      2022    303.216667
# ACURA        1995           NaN
# Name: CO2 EMISSIONS, Length: 232, dtype: float64

# %% [markdown]
# DET ER DET HER OUTPUT VI HAR KUNNE KOMME FREM TIL SIDDET MED DET HELE DAGEN

# %%
df_fuel.loc[df_fuel['MAKE'] == 'BUICK']
# Out:
#      YEAR   MAKE          MODEL             VEHICLE CLASS  ENGINE SIZE(L)  \
# 51   1995  BUICK        CENTURY                  MID-SIZE             2.2
# 52   1995  BUICK        CENTURY                  MID-SIZE             3.1
# 53   1995  BUICK  CENTURY WAGON  STATION WAGON - MID-SIZE             2.2
# 54   1995  BUICK  CENTURY WAGON  STATION WAGON - MID-SIZE             3.1
# 55   1995  BUICK        LESABRE                 FULL-SIZE             3.8
# ..    ...    ...            ...                       ...             ...
# 139  2022  BUICK      ENCORE GX                SUV: SMALL             1.2
# 140  2022  BUICK      ENCORE GX                SUV: SMALL             1.3
# 141  2022  BUICK  ENCORE GX AWD                SUV: SMALL             1.3
# 142  2022  BUICK       ENVISION                SUV: SMALL             2.0
# 143  2022  BUICK   ENVISION AWD                SUV: SMALL             2.0
#
#      CYLINDERS TRANSMISSION FUELTYPE  CITY (L/100 km)  HWY (L/100 km)  \
# 51           4           A3        X             11.3             8.2
# 52           6           A4        X             14.6             9.3
# 53           4           A3        X             12.3             8.7
# 54           6           A4        X             14.6             9.3
# 55           6           A4        X             14.5             9.3
# ..         ...          ...      ...              ...             ...
# 139          3           AV        X              8.0             7.6
# 140          3           AV        X              8.2             7.4
# 141          3           A9        X              9.0             8.2
# 142          4          AS9        X             10.0             7.6
# 143          4          AS9        X             10.5             8.2
#
#      COMB (L/100 km)  CO2 EMISSIONS
# 51               9.9            228
# 52              12.2            281
# 53              10.7            246
# 54              12.2            281
# 55              12.1            278
# ..               ...            ...
# 139              7.8            184
# 140              7.9            185
# 141              8.6            201
# 142              8.9            209
# 143              9.5            220
#
# [64 rows x 12 columns]

# %%
df_fuel.groupby(['MAKE']).agg({'YEAR': ['max', 'min'], 'CO2 EMISSIONS': 'mean'})
# Out:
#                YEAR       CO2 EMISSIONS
#                 max   min          mean
# MAKE
# ACURA          2022  1995    252.688525
# ALFA ROMEO     2022  1995    259.250000
# ASTON MARTIN   2022  2022    306.400000
# AUDI           2022  1995    266.329897
# BENTLEY        2022  1995    438.000000
# BMW            2022  1995    276.984293
# BUGATTI        2022  2022    579.333333
# BUICK          2022  1995    267.093750
# CADILLAC       2022  1995    286.921569
# CHEVROLET      2022  1995    326.599109
# CHRYSLER       2022  1995    277.040000
# DAEWOO         1999  1999    227.714286
# DODGE          2022  1995    342.106383
# EAGLE          1998  1995    252.536585
# FERRARI        1999  1995    503.533333
# FIAT           2022  2022    221.000000
# FORD           2022  1995    313.093023
# GENESIS        2022  2022    266.250000
# GEO            1997  1995    208.631579
# GMC            2022  1995    357.735786
# HONDA          2022  1995    221.666667
# HYUNDAI        2022  1995    216.926829
# INFINITI       2022  1995    277.862069
# ISUZU          1999  1995    334.931034
# JAGUAR         2022  1995    317.081081
# JEEP           2022  1995    312.705882
# KIA            2022  2022    194.200000
# LAMBORGHINI    2022  2022    418.875000
# LAND ROVER     2022  1995    358.200000
# LEXUS          2022  1995    260.846154
# LINCOLN        2022  1995    298.571429
# MASERATI       2022  2022    307.307692
# MAZDA          2022  1995    258.506173
# MERCEDES-BENZ  2022  1995    288.318519
# MERCURY        1999  1995    266.122807
# MINI           2022  2022    192.400000
# MITSUBISHI     2022  2022    193.571429
# NISSAN         2022  1995    258.984127
# OLDSMOBILE     1999  1995    276.022222
# PLYMOUTH       1999  1995    265.802326
# PONTIAC        1999  1995    255.649635
# PORSCHE        2022  1995    295.174757
# RAM            2022  2022    289.250000
# ROLLS-ROYCE    2022  1995    437.900000
# SAAB           1999  1995    277.548387
# SATURN         1999  1995    206.200000
# SUBARU         2022  1995    241.282609
# SUZUKI         1999  1995    226.131148
# TOYOTA         2022  1995    249.603376
# VOLKSWAGEN     2022  1995    252.538462
# VOLVO          2022  1995    268.536082

# %% [markdown]
# ### What year, between 1995 and 1999, was there the most pollution?

# %%
df_fuel.groupby('YEAR').mean()
# Out:
#       ENGINE SIZE(L)  CYLINDERS  CITY (L/100 km)  HWY (L/100 km)  \
# YEAR
# 1995        3.443520   5.846611        15.078835       11.057313
# 1996        3.313610   5.707736        14.624355       10.615759
# 1997        3.318541   5.747720        14.646049       10.588298
# 1998        3.351262   5.788644        14.793691       10.637382
# 1999        3.290116   5.799419        14.711628       10.646802
# 2022        3.198732   5.668076        12.506448        9.363319
#
#       COMB (L/100 km)  CO2 EMISSIONS
# YEAR
# 1995        13.268609     307.577883
# 1996        12.822063     296.186246
# 1997        12.818693     295.861702
# 1998        12.927129     297.990536
# 1999        12.882849     295.562500
# 2022        11.092072     259.172304

# %% [markdown]
# 1995 had the most pollution recording to the table above
